# %%
import toml
from analysis import Analysis

# %%
cfg = """
[[this_includes]]
file = 'configurations/common/variables.toml'

[[this_includes]]
file = 'configurations/common/styles.toml'

[samples]
[samples.mc]
key = "mc"
exposure_type = "pot"
trees = ['selectedNu','selectedCos']

[output]
path = '/Users/mueller/Downloads/tmp'

[analysis]
ordinate_sample = 'mc'
category_branch = 'category'
category_assignment = [[0,2], [1,3,4,5,6], [7], [-1,8]]
category_labels = ['1$\\mu$Np', 'Other CC $\\nu$', 'NC $\\nu$', 'Cosmic']
category_colors = ['C0', 'C1', 'C3', 'C4', 'black']
category_types = ['histogram', 'histogram', 'histogram', 'histogram']

[[figure]]
name = 'reco_edep'
type = 'SimpleFigure'
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_visible_energy'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}
"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = '/Users/mueller/data/muon2024.root'

analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# Setting weight for mc to 1.00e+00

# %%
# Example plots of 1d and 2d histograms using customized bins
# This example uses the medulla output file example01_ccqe.root
# generated with toml file: 
# medulla/tutorial/examples/example01_ccqe.toml

cfg = r"""

[[style]]
name = 'selected_icarus'
style_sheet = 'path/to/your/style_sheet.mplstyle"
markers = ['o', '^', 's', 'P', 'D']
default_figsize = [8,6]
title = '$\bf{ICARUS}$ $1\mu1p$ CC0$\pi$'
mark_pot = true
mark_preliminary = '$\bf{ICARUS}$ Work-in-Progress'
plot_kwargs = {'histtype' = 'barstacked', 'stacked' = true}

[variables]
[variables.reco_visible_energy]
key = 'reco_visible_energy'
range = [0.0, 2.0]
nbins = 20
# range and nbins will be overwritten given custom_bins
binning_scheme = 'custom_bins'
custom_bins = [0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.0, 1.1, 1.2, 1.3, 1.4, 1.6, 1.8, 2.0]
xlabel = 'Reconstructed Visible Energy [GeV/c$^{2}$]'


[variables.true_visible_energy]
key = 'true_visible_energy'
range = [0.0, 2.0]
nbins = 20
# range and nbins will be overwritten given custom_bins
binning_scheme = 'custom_bins'
custom_bins = [0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.0, 1.1, 1.2, 1.3, 1.4, 1.6, 1.8, 2.0]
xlabel = 'True Visible Energy [GeV/c$^{2}$]'


[samples]
[samples.mc]
key = "simulation"
exposure_type = "pot"
trees = ['selected']

[output]
path = '.'

[analysis]
ordinate_sample = 'mc'
category_branch = 'true_category'

category_assignment = [[0], [1,2,3], [4,5],[6], [7]]
category_labels = ['Signal','OOFV', 'Other CC', 'NC', 'Cosmic']
category_colors = ['C0', 'C1', 'C3', 'C4', 'black']
category_types = ['histogram', 'histogram', 'histogram', 'histogram', 'histogram']

[[figure]]
name = 'reco_visible_energy'
type = 'SimpleFigure'
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_visible_energy'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'true_vs_reco_visible_energy_2d'
type = 'SimpleFigure'
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra2D'
xvariable = 'reco_visible_energy'
yvariable = 'true_visible_energy'
ytitle = 'Candidates'

"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = 'path/to/your/example01_ccqe.root'


analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# Setting weight for mc to 1.00e+00
